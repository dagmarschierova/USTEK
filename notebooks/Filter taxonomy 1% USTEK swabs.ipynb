# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/dagmarschierova/MEGA/MBÚ/swabs_ZS/outputs/qiime2_results_290230/taxonomy_no_raref_D_UST/taxonomy-L7-rel.tsv", 
                 sep='\t', skiprows=1, index_col=0)
df

# %%
df = df.drop(df[(df < 0.01).all(axis=1)].index)
df

# %%
df.to_csv('/Users/dagmarschierova/MEGA/MBÚ/swabs_ZS/outputs/qiime2_results_290230/taxonomy_no_raref_D_UST/taxonomy-L7-rel-filtered1perc.tsv', 
         sep='\t')

# %%
df2 = pd.read_csv("/Users/dagmarschierova/MEGA/MBÚ/swabs_ZS/outputs/qiime2_results_290230/taxonomy_no_raref_D_UST_week040/taxonomy-L7-rel.tsv", 
                 sep='\t', skiprows=1, index_col=0)
df2
# Out:
#                                                     P11_GT85_I_D  \
# #OTU ID
# Unassigned;__;__;__;__;__;__                            0.016818
# d__Bacteria;p__Actinobacteriota;c__Acidimicrobi...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# ...                                                          ...
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.000000
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.000000
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.000000
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.000000
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.000000
#
#                                                     P11_GT85_VI_D  \
# #OTU ID
# Unassigned;__;__;__;__;__;__                             0.001724
# ...

# %%
df2 = df2.drop(df2[(df2 < 0.01).all(axis=1)].index)
df2
# Out:
#                                                     P11_GT85_I_D  \
# #OTU ID
# Unassigned;__;__;__;__;__;__                            0.016818
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.012220
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.001331
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.858318
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...      0.000000
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...      0.000000
# d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__B...      0.000000
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...      0.000000
# ...

# %%
df2.to_csv('/Users/dagmarschierova/MEGA/MBÚ/swabs_ZS/outputs/qiime2_results_290230/taxonomy_no_raref_D_UST_week040/taxonomy-L7-rel-filtered1perc.tsv', 
         sep='\t')

# %%
df3 = pd.read_csv("/Users/dagmarschierova/MEGA/MBÚ/swabs_ZS/outputs/qiime2_results_290230/taxonomy_no_raref_D_UST/taxonomy-patients-L7-rel.tsv", 
                 sep='\t', skiprows=1, index_col=0)
df3
# Out:
#                                                     P11_GT85_I_D  \
# #OTU ID
# Unassigned;__;__;__;__;__;__                            0.016818
# d__Archaea;p__Halobacterota;c__Halobacteria;o__...      0.000000
# d__Bacteria;p__Acidobacteriota;c__Acidobacteria...      0.000000
# d__Bacteria;p__Acidobacteriota;c__Acidobacteria...      0.000000
# d__Bacteria;p__Acidobacteriota;c__Acidobacteria...      0.000000
# ...                                                          ...
# d__Bacteria;p__Spirochaetota;c__Spirochaetia;o_...      0.000000
# d__Bacteria;p__Spirochaetota;c__Spirochaetia;o_...      0.000000
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...      0.000000
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...      0.000000
# d__Bacteria;p__Verrucomicrobiota;c__Verrucomicr...      0.000000
#
#                                                     P11_GT85_II_D  \
# #OTU ID
# Unassigned;__;__;__;__;__;__                             0.008899
# ...

# %%
df3 = df3.drop(df3[(df3 < 0.01).all(axis=1)].index)
df3
# Out:
#                                                     P11_GT85_I_D  \
# #OTU ID
# Unassigned;__;__;__;__;__;__                            0.016818
# d__Bacteria;p__Acidobacteriota;c__Acidobacteria...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# d__Bacteria;p__Actinobacteriota;c__Actinobacter...      0.000000
# ...                                                          ...
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.001089
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.000000
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.000000
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.000000
# d__Bacteria;p__Proteobacteria;c__Gammaproteobac...      0.000000
#
#                                                     P11_GT85_II_D  \
# #OTU ID
# Unassigned;__;__;__;__;__;__                             0.008899
# ...

# %%
df3.to_csv('/Users/dagmarschierova/MEGA/MBÚ/swabs_ZS/outputs/qiime2_results_290230/taxonomy_no_raref_D_UST/taxonomy-patinents-L7-rel-filtered1perc.tsv', 
         sep='\t')
